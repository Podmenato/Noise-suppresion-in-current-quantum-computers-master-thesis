# %%
from utilities import load_variation_distances, vd_int
import numpy as np
import matplotlib.pyplot as plt

# %%
real_device_vd_prob = vd_int([286, 4678, 5329], [0, 2*np.sin(0.5)**2, np.cos(2*0.5)])
real_device_vd_seq = vd_int([1543, 8511, 9946], [0, 2*np.sin(0.5)**2, np.cos(2*0.5)])

real_device_vd_prob_1 = vd_int([19, 218, 271], [0, 2*np.sin(0.5)**2, np.cos(2*0.5)])
real_device_vd_seq_1 = vd_int([70, 372, 558], [0, 2*np.sin(0.5)**2, np.cos(2*0.5)])

# %%
scales = np.linspace(0, 1, 15)
vd_seq = load_variation_distances("output/usd1_seq_1000.txt")
v_distances = [[] for scale in scales]
for i in range(len(vd_seq)):
    for j in range(len(scales)):
        v_distances[j].append(vd_seq[i][j])

for i in range(len(v_distances)):
    v_distances[i] = np.array(v_distances[i])

vd_prob = load_variation_distances("output/usd1_prob_1000.txt")
v_distances_prob = [[] for scale in scales]
for i in range(len(vd_prob)):
    for j in range(len(scales)):
        v_distances_prob[j].append(vd_prob[i][j])

for i in range(len(v_distances_prob)):
    v_distances_prob[i] = np.array(v_distances_prob[i])

vd_seq_sc = load_variation_distances("output/usd1_single_c_1000.txt")

v_distances_seq_sc = [[] for scale in scales]
for i in range(len(vd_seq_sc)):
    for j in range(len(scales)):
        v_distances_seq_sc[j].append(vd_seq_sc[i][j])

for i in range(len(v_distances_seq_sc)):
    v_distances_seq_sc[i] = np.array(v_distances_seq_sc[i])


## Figure initialization
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
ax.grid(True)
ax.set_title("Total variation distance between ideal and noisy evolution")
ax.set_ylabel("TVD")
ax.set_xlabel("noise rate")

ax.errorbar(scales, [v_i.mean() for v_i in v_distances], yerr=[v_i.std() for v_i in v_distances], fmt="-ob", label="MCS simulator")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_prob], yerr=[v_i.std() for v_i in v_distances_prob], fmt="-oc", label="PB simulator")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_seq_sc], yerr=[v_i.std() for v_i in v_distances_seq_sc], fmt="-or", label="SCS simulator")
plt.axhline(y=real_device_vd_prob_1, color='c', linestyle='--', label="MCS real device")
plt.axhline(y=real_device_vd_seq_1, color='b', linestyle='--', label="PB real device")

ax.legend()

plt.show()

# %%
scales = np.linspace(0, 1, 15)
vd_seq = load_variation_distances("output/usd1_seq_5000.txt")
v_distances = [[] for scale in scales]
for i in range(len(vd_seq)):
    for j in range(len(scales)):
        v_distances[j].append(vd_seq[i][j])

for i in range(len(v_distances)):
    v_distances[i] = np.array(v_distances[i])

vd_prob = load_variation_distances("output/usd1_prob_5000.txt")
v_distances_prob = [[] for scale in scales]
for i in range(len(vd_prob)):
    for j in range(len(scales)):
        v_distances_prob[j].append(vd_prob[i][j])

for i in range(len(v_distances_prob)):
    v_distances_prob[i] = np.array(v_distances_prob[i])

vd_seq_sc = load_variation_distances("output/usd1_single_c_5000.txt")

v_distances_seq_sc = [[] for scale in scales]
for i in range(len(vd_seq_sc)):
    for j in range(len(scales)):
        v_distances_seq_sc[j].append(vd_seq_sc[i][j])

for i in range(len(v_distances_seq_sc)):
    v_distances_seq_sc[i] = np.array(v_distances_seq_sc[i])


## Figure initialization
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
ax.grid(True)
ax.set_title("Total variation distance between ideal and noisy evolution")
ax.set_ylabel("TVD")
ax.set_xlabel("noise rate")

ax.errorbar(scales, [v_i.mean() for v_i in v_distances], yerr=[v_i.std() for v_i in v_distances], fmt="-ob", label="Sequential alt")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_prob], yerr=[v_i.std() for v_i in v_distances_prob], fmt="-oc", label="Probabilistic")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_seq_sc], yerr=[v_i.std() for v_i in v_distances_seq_sc], fmt="-or", label="Sequential sg circ")
plt.axhline(y=real_device_vd_prob, color='c', linestyle='--')
plt.axhline(y=real_device_vd_seq, color='b', linestyle='--')

ax.legend()

plt.show()

# %%
scales = np.linspace(0, 1, 15)
vd_seq = load_variation_distances("output/usd1_seq_10000.txt")
v_distances = [[] for scale in scales]
for i in range(len(vd_seq)):
    for j in range(len(scales)):
        v_distances[j].append(vd_seq[i][j])

for i in range(len(v_distances)):
    v_distances[i] = np.array(v_distances[i])

vd_prob = load_variation_distances("output/usd1_prob_10000.txt")
v_distances_prob = [[] for scale in scales]
for i in range(len(vd_prob)):
    for j in range(len(scales)):
        v_distances_prob[j].append(vd_prob[i][j])

for i in range(len(v_distances_prob)):
    v_distances_prob[i] = np.array(v_distances_prob[i])

vd_seq_sc = load_variation_distances("output/usd1_single_c_10000.txt")

v_distances_seq_sc = [[] for scale in scales]
for i in range(len(vd_seq_sc)):
    for j in range(len(scales)):
        v_distances_seq_sc[j].append(vd_seq_sc[i][j])

for i in range(len(v_distances_seq_sc)):
    v_distances_seq_sc[i] = np.array(v_distances_seq_sc[i])


## Figure initialization
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
ax.grid(True)
ax.set_title("Total variation distance between ideal and noisy evolution")
ax.set_ylabel("TVD")
ax.set_xlabel("noise rate")

ax.errorbar(scales, [v_i.mean() for v_i in v_distances], yerr=[v_i.std() for v_i in v_distances], fmt="-ob", label="Sequential alt")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_prob], yerr=[v_i.std() for v_i in v_distances_prob], fmt="-oc", label="Probabilistic")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_seq_sc], yerr=[v_i.std() for v_i in v_distances_seq_sc], fmt="-or", label="Sequential sg circ")
plt.axhline(y=real_device_vd_prob, color='c', linestyle='--')
plt.axhline(y=real_device_vd_seq, color='b', linestyle='--')

ax.legend()

plt.show()

# %%
scales = np.linspace(0, 1, 15)
vd_seq = load_variation_distances("output/usd1_seq_15000.txt")
v_distances = [[] for scale in scales]
for i in range(len(vd_seq)):
    for j in range(len(scales)):
        v_distances[j].append(vd_seq[i][j])

for i in range(len(v_distances)):
    v_distances[i] = np.array(v_distances[i])

vd_prob = load_variation_distances("output/usd1_prob_15000.txt")
v_distances_prob = [[] for scale in scales]
for i in range(len(vd_prob)):
    for j in range(len(scales)):
        v_distances_prob[j].append(vd_prob[i][j])

for i in range(len(v_distances_prob)):
    v_distances_prob[i] = np.array(v_distances_prob[i])

vd_seq_sc = load_variation_distances("output/usd1_single_c_15000.txt")

v_distances_seq_sc = [[] for scale in scales]
for i in range(len(vd_seq_sc)):
    for j in range(len(scales)):
        v_distances_seq_sc[j].append(vd_seq_sc[i][j])

for i in range(len(v_distances_seq_sc)):
    v_distances_seq_sc[i] = np.array(v_distances_seq_sc[i])


## Figure initialization
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
ax.grid(True)
ax.set_title("Total variation distance between ideal and noisy evolution")
ax.set_ylabel("TVD")
ax.set_xlabel("noise rate")

ax.errorbar(scales, [v_i.mean() for v_i in v_distances], yerr=[v_i.std() for v_i in v_distances], fmt="-ob", label="Sequential alt")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_prob], yerr=[v_i.std() for v_i in v_distances_prob], fmt="-oc", label="Probabilistic")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_seq_sc], yerr=[v_i.std() for v_i in v_distances_seq_sc], fmt="-or", label="Sequential sg circ")
plt.axhline(y=real_device_vd_prob, color='c', linestyle='--')
plt.axhline(y=real_device_vd_seq, color='b', linestyle='--')

ax.legend()

plt.show()

# %%
scales = np.linspace(0, 1, 15)
vd_seq = load_variation_distances("output/usd1_seq_20000.txt")
v_distances = [[] for scale in scales]
for i in range(len(vd_seq)):
    for j in range(len(scales)):
        v_distances[j].append(vd_seq[i][j])

for i in range(len(v_distances)):
    v_distances[i] = np.array(v_distances[i])

vd_prob = load_variation_distances("output/usd1_prob_20000.txt")
v_distances_prob = [[] for scale in scales]
for i in range(len(vd_prob)):
    for j in range(len(scales)):
        v_distances_prob[j].append(vd_prob[i][j])

for i in range(len(v_distances_prob)):
    v_distances_prob[i] = np.array(v_distances_prob[i])

vd_seq_sc = load_variation_distances("output/usd1_single_c_20000.txt")

v_distances_seq_sc = [[] for scale in scales]
for i in range(len(vd_seq_sc)):
    for j in range(len(scales)):
        v_distances_seq_sc[j].append(vd_seq_sc[i][j])

for i in range(len(v_distances_seq_sc)):
    v_distances_seq_sc[i] = np.array(v_distances_seq_sc[i])


## Figure initialization
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
ax.grid(True)
ax.set_title("Total variation distance between ideal and noisy evolution")
ax.set_ylabel("TVD")
ax.set_xlabel("noise rate")

ax.errorbar(scales, [v_i.mean() for v_i in v_distances], yerr=[v_i.std() for v_i in v_distances], fmt="-ob", label="MCS simulator")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_prob], yerr=[v_i.std() for v_i in v_distances_prob], fmt="-oc", label="PB simulator")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_seq_sc], yerr=[v_i.std() for v_i in v_distances_seq_sc], fmt="-or", label="SCS simulator")
plt.axhline(y=real_device_vd_prob, color='c', linestyle='--', label="MCS real device")
plt.axhline(y=real_device_vd_seq, color='b', linestyle='--', label="PB real device")

ax.legend()

plt.show()

# %%
shots = [1000, 5000, 10000, 15000, 20000]

vd_seq_shots = []
for shot in shots:
    vd_seq_shots_current = []
    loaded_file = load_variation_distances(f"output/usd1_seq_{shot}.txt")
    for meas in loaded_file:
        vd_seq_shots_current.append(meas[0])
    vd_seq_shots.append(np.array(vd_seq_shots_current))

vd_prob_shots = []
for shot in shots:
    vd_prob_shots_current = []
    loaded_file = load_variation_distances(f"output/usd1_prob_{shot}.txt")
    for meas in loaded_file:
        vd_prob_shots_current.append(meas[0])
    vd_prob_shots.append(np.array(vd_prob_shots_current))

vd_single_c_shots = []
for shot in shots:
    vd_single_c_shots_current = []
    loaded_file = load_variation_distances(f"output/usd1_single_c_{shot}.txt")
    for meas in loaded_file:
        vd_single_c_shots_current.append(meas[0])
    vd_single_c_shots.append(np.array(vd_single_c_shots_current))



## Figure initialization
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
ax.grid(True)
ax.set_title("Total variation distance between ideal and noisy evolution")
ax.set_ylabel("TVD")
ax.set_xlabel("shots")

ax.errorbar(shots, [v_i.mean() for v_i in vd_seq_shots], yerr=[v_i.std() for v_i in vd_seq_shots], fmt="-ob", label="Sequential alt")
ax.errorbar(shots, [v_i.mean() for v_i in vd_prob_shots], yerr=[v_i.std() for v_i in vd_prob_shots], fmt="-oc", label="Probabilistic")
ax.errorbar(shots, [v_i.mean() for v_i in vd_single_c_shots], yerr=[v_i.std() for v_i in vd_single_c_shots], fmt="-or", label="Sequential sg circ")

ax.legend()

plt.show()

# %%
shots = [1000, 5000, 10000, 15000, 20000]

vd_seq_shots = []
for shot in shots:
    vd_seq_shots_current = []
    loaded_file = load_variation_distances(f"output/usd1_seq_{shot}.txt")
    for meas in loaded_file:
        vd_seq_shots_current.append(meas[0])
    vd_seq_shots.append(np.array(vd_seq_shots_current))

vd_seq_shots_noisy = []
for shot in shots:
    vd_seq_shots_current = []
    loaded_file = load_variation_distances(f"output/usd1_seq_{shot}.txt")
    for meas in loaded_file:
        vd_seq_shots_current.append(meas[14])
    vd_seq_shots_noisy.append(np.array(vd_seq_shots_current))

vd_prob_shots = []
for shot in shots:
    vd_prob_shots_current = []
    loaded_file = load_variation_distances(f"output/usd1_prob_{shot}.txt")
    for meas in loaded_file:
        vd_prob_shots_current.append(meas[0])
    vd_prob_shots.append(np.array(vd_prob_shots_current))

vd_prob_shots_noisy = []
for shot in shots:
    vd_prob_shots_current = []
    loaded_file = load_variation_distances(f"output/usd1_prob_{shot}.txt")
    for meas in loaded_file:
        vd_prob_shots_current.append(meas[14])
    vd_prob_shots_noisy.append(np.array(vd_prob_shots_current))

vd_single_c_shots = []
for shot in shots:
    vd_single_c_shots_current = []
    loaded_file = load_variation_distances(f"output/usd1_single_c_{shot}.txt")
    for meas in loaded_file:
        vd_single_c_shots_current.append(meas[0])
    vd_single_c_shots.append(np.array(vd_single_c_shots_current))

vd_single_c_shots_noisy = []
for shot in shots:
    vd_single_c_shots_current = []
    loaded_file = load_variation_distances(f"output/usd1_single_c_{shot}.txt")
    for meas in loaded_file:
        vd_single_c_shots_current.append(meas[14])
    vd_single_c_shots_noisy.append(np.array(vd_single_c_shots_current))



## Figure initialization
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
ax.grid(True)
ax.set_title("Standard deviation with increasing shots")
ax.set_ylabel("STD")
ax.set_xlabel("shots")

ax.plot(shots, [v_i.std() for v_i in vd_seq_shots],"-ob", label="MCS noiseless")
ax.plot(shots, [v_i.std() for v_i in vd_seq_shots_noisy],"--b", label="MCS noisy")
ax.plot(shots, [v_i.std() for v_i in vd_prob_shots], "-oc", label="PB noiseless")
ax.plot(shots, [v_i.std() for v_i in vd_prob_shots_noisy], "--c", label="PB noisy")
ax.plot(shots, [v_i.std() for v_i in vd_single_c_shots],"-or", label="SCS noiseless")
ax.plot(shots, [v_i.std() for v_i in vd_single_c_shots_noisy],"--r", label="SCS noisy")

ax.legend()

plt.show()

# %%
scales = np.linspace(0, 1, 15)
vd_seq = load_variation_distances("output/usd_error_seq_20000.txt")
v_distances = [[] for scale in scales]
for i in range(len(vd_seq)):
    for j in range(len(scales)):
        v_distances[j].append(vd_seq[i][j])

for i in range(len(v_distances)):
    v_distances[i] = np.array(v_distances[i])

vd_prob = load_variation_distances("output/usd_error_prob_20000.txt")
v_distances_prob = [[] for scale in scales]
for i in range(len(vd_prob)):
    for j in range(len(scales)):
        v_distances_prob[j].append(vd_prob[i][j])

for i in range(len(v_distances_prob)):
    v_distances_prob[i] = np.array(v_distances_prob[i])

vd_seq_sc = load_variation_distances("output/usd_error_single_c_20000.txt")

v_distances_seq_sc = [[] for scale in scales]
for i in range(len(vd_seq_sc)):
    for j in range(len(scales)):
        v_distances_seq_sc[j].append(vd_seq_sc[i][j])

for i in range(len(v_distances_seq_sc)):
    v_distances_seq_sc[i] = np.array(v_distances_seq_sc[i])


## Figure initialization
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
ax.grid(True)
ax.set_title("Wrong state measured with increasing noise levels")
ax.set_ylabel("Wrong state measured")
ax.set_xlabel("noise rate")

ax.errorbar(scales, [v_i.mean() for v_i in v_distances], yerr=[v_i.std() for v_i in v_distances], fmt="-ob", label="MCS simulator")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_prob], yerr=[v_i.std() for v_i in v_distances_prob], fmt="-oc", label="PB simulator")
ax.errorbar(scales, [v_i.mean() for v_i in v_distances_seq_sc], yerr=[v_i.std() for v_i in v_distances_seq_sc], fmt="-or", label="SCS simulator")
plt.axhline(y=286, color='c', linestyle='--', label="MCS real device")
plt.axhline(y=1543, color='b', linestyle='--', label="PB real device")

ax.legend()

plt.show()
